# %% [markdown]
# # Module 11 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html=browser.html
soup=soup(html,'html.parser')

# %%
# Extract all rows of data
all_rows=soup.find_all('td')

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
row_list=[]
# Loop through the scraped data to create a list of rows
for rows in all_rows:
    rows_text=rows.text
    row_list.append(rows_text)
#print(row_list)
counter = 0  # Initialize a counter variable
row_dt_list = []  # Create an empty list to store the extracted groups of elements
while counter + 6 < len(row_list):
    row_dt = (row_list[counter], row_list[counter+1], row_list[counter+2], row_list[counter+3], row_list[counter+4], row_list[counter+5], row_list[counter+6])
    row_dt_list.append(row_dt)
    counter += 7
print(row_dt_list)
# Out:
# [('2', '2012-08-16', '10', '155', '6', '-75.0', '739.0'), ('13', '2012-08-17', '11', '156', '6', '-76.0', '740.0'), ('24', '2012-08-18', '12', '156', '6', '-76.0', '741.0'), ('35', '2012-08-19', '13', '157', '6', '-74.0', '732.0'), ('46', '2012-08-20', '14', '157', '6', '-74.0', '740.0'), ('57', '2012-08-21', '15', '158', '6', '-78.0', '740.0'), ('68', '2012-08-22', '16', '158', '6', '-77.0', '740.0'), ('79', '2012-08-23', '17', '159', '6', '-76.0', '742.0'), ('112', '2012-08-27', '21', '161', '6', '-74.0', '741.0'), ('114', '2012-08-28', '22', '162', '6', '-74.0', '742.0'), ('123', '2012-08-29', '23', '162', '6', '-75.0', '741.0'), ('134', '2012-08-30', '24', '163', '6', '-75.0', '742.0'), ('145', '2012-08-31', '25', '163', '6', '-75.0', '743.0'), ('156', '2012-09-01', '26', '164', '6', '-76.0', '745.0'), ('163', '2012-09-02', '27', '164', '6', '-75.0', '743.0'), ('170', '2012-09-03', '28', '165', '6', '-75.0', '745.0'), ('171', '2012-09-04', '29', '166', '6', '-75.0', '747.0'), ('1
# ...

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
columns='id', 'terrestrial_date','sol','ls','month','min_temp','pressure'
mars_df = pd.DataFrame(row_dt_list, columns=columns)

# %%
# Confirm DataFrame was created successfully
mars_df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column

print (mars_df.dtypes)
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
mars_df['terrestrial_date'] = pd.to_datetime(mars_df['terrestrial_date'])
mars_df['sol']=mars_df['sol'].astype(int)
mars_df['ls']=mars_df['ls'].astype(int)
mars_df['month']=mars_df['month'].astype(int)
mars_df['min_temp']=mars_df['min_temp'].astype(float)
mars_df['pressure']=mars_df['pressure'].astype(float)

# %%
# Confirm type changes were successful by examining data types again
mars_df.dtypes
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int32
# ls                           int32
# month                        int32
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
print(mars_df['month'].nunique())
month_counts = mars_df['month'].value_counts().sort_index()
month_counts
# Out:
# 12
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: count, dtype: int64

# %%
# 2. How many sols (Martian days) worth of data are there?
mars_df['sol'].nunique()
# Out:
# 1867

# %%
# 3. What is the average low temperature by month?
low_temp_mean = mars_df.groupby('month')['min_temp'].mean()
low_temp_mean
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average minimum temperature by month
low_temp_mean.plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
# Identify the coldest and hottest months in Curiosity's location by sorting the previous graph
curiosity_temp =low_temp_mean.sort_values()
temp_list=curiosity_temp.to_list()
temp_list
coldest_temp=temp_list[0]
hotest_temp=temp_list[-1]
coldest_month = low_temp_mean.idxmin()
hotest_month = low_temp_mean.idxmax()
print(f"Coldest month is {coldest_month} with temperature {coldest_temp}")
print(f"Hotest month is {hotest_month} with temperature {hotest_temp}")
curiosity_temp.plot(kind='bar')
# Out:
# Coldest month is 3 with temperature -83.30729166666667
# Hotest month is 8 with temperature -68.38297872340425
# <Axes: xlabel='month'>

# %%
# 4. Average pressure by Martian month
pressure_mean = mars_df.groupby('month')['pressure'].mean()
pressure_mean
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month
pressure_mean.plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
# Identify the lowest and highest pressure months in Curiosity's location by sorting the previous graph
pressure_mean_sort = pressure_mean.sort_values()
pressure_mean_sort.plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?
terrestrial_days = (mars_df['terrestrial_date'] - mars_df['terrestrial_date'].min()).dt.days

# Create a plot with 'Terrestrial Days' on the x-axis and 'Minimum Temperature' on the y-axis
plt.plot(terrestrial_days, mars_df['min_temp'], label='Minimum Temperature')

# Add a vertical line along the x-axis at a specific 'Terrestrial Days' value
vertical_line_x = 50  # You can change this value to the desired 'Terrestrial Days' value
plt.axvline(1040, color='y', linestyle='--', label=f'X-Axis Line at {vertical_line_x}')
plt.axvline(1730, color='y', linestyle='--', label=f'X-Axis Line at {vertical_line_x}')
print("A Martian year has roughly around 690 days from the plot")

# Add labels and a legend
plt.xlabel('Terrestrial Days')
plt.ylabel('Minimum Temperature')


# Show the plot
plt.show()
# Out:
# A Martian year has roughly around 690 days from the plot

# %% [markdown]
# #### Minimum Temperature
# This analysis focuses on the average minimum temperature by month. By plotting the low_temp_mean dataset, we can visualize temperature trends over different months and identify seasonal variations. This helps in understanding patterns such as colder months and potential climate shifts.
#
# The bar charts offers a effective way to compare monthly minimum temperatures, moving forward maiking is easier to see patterns.

# %% [markdown]
# #### Atmospheric Pressure
# This analysis examines the avrage atmospheric pressure on Mars by month.By createing visuals using the current data we could identify the months with the highest and lowest pressure levels.The different variations of pressure change can help us see to understand weather trends so we know what to expect for future exploration.

# %% [markdown]
# #### Year Length
# A Martian year is approximately 690 Earth days, as shown in the plot. Seasonal patterns and temperature variations help determine this cycle. Understanding the year length is crucial for mission planning and studying Mars' climate.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
file_name = 'mars_data.csv'
# Write the data from the DataFrame to the CSV file
mars_df.to_csv(file_name, index=False)  # Set index=False to exclude the DataFrame index column

print(f'Data has been written to {file_name}')
# Out:
# Data has been written to mars_data.csv

# %%
browser.quit()
